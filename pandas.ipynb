# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
# Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl (12.5 MB)
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#   Using cached pip-26.1.1-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.1.1-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0.1
#     Uninstalling pip-26.0.1:
#       Successfully uninstalled pip-26.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data=[10,20,30,40,50]
ps=pd.Series(data,index=["a","b","c","d","e"],dtype="float",name="Float Number")
print(ps)
# Out:
# a    10.0
# b    20.0
# c    30.0
# d    40.0
# e    50.0
# Name: Float Number, dtype: float64

# %%
data_set={
    "Subject":["Physics","CHEM","MATH"],
    "Marks":[98,99,100],
    "Grade":["A","A","A+"]
}
df=pd.DataFrame(data_set,index=["a","b","c"])
print(df)
print(data_set["Marks"][0])
# Out:
#    Subject  Marks Grade
# a  Physics     98     A
# b     CHEM     99     A
# c     MATH    100    A+
# 98

# %%
dt={"day1":[420,450],"day2":[480],"day3":[500,501]}
pf=pd.Series(dt)
res=pf.tolist()
print(res)
print(myVar)
# Out:
# [[420, 450], [480], [500, 501]]
#    day1  day2  day3
# 0   420   450   500
# 1   450   480   501

# %%
data={
    "qmarks":[420,380,750],
    "duration":[50,60,80]
}
df=pd.DataFrame(data)
df.index=["d1","d2","d3"]
df.columns=["col1","col2"]
print(df)
# Out:
#     col1  col2
# d1   420    50
# d2   380    60
# d3   750    80

# %%
df=pd.DataFrame([['a','b'],['c','d'],['e','f'],['g','h']],columns=["col1","col2"])
print(df)

df.index=["d1","d2","d3","d4"]
print(df)
result=df.loc['d1':'d3','col1']
print(result)
# Out:
#   col1 col2
# 0    a    b
# 1    c    d
# 2    e    f
# 3    g    h
#    col1 col2
# d1    a    b
# d2    c    d
# d3    e    f
# d4    g    h
# d1    a
# d2    c
# d3    e
# Name: col1, dtype: str

# %%
df1=pd.DataFrame([['a','b','f','g'],['c','d','h','i'],['e','f','j','k'],[0,'h','i','k']],columns=['col1','col2','col3','col4'])
df1.index=["d1","d2","d3","d4"]
df1.iloc[0,0:2]=['x','y']
res=df1['col1']!=0
print(result)
print(df1)
print(res)
res=df1[df1['col1']!=0]
print(res)
# Out:
# ['x', 'y', 'z']
#    col1 col2 col3 col4
# d1    x    y    f    g
# d2    c    d    h    i
# d3    e    f    j    k
# d4    0    h    i    k
# d1     True
# d2     True
# d3     True
# d4    False
# Name: col1, dtype: bool
#    col1 col2 col3 col4
# d1    x    y    f    g
# d2    c    d    h    i
# d3    e    f    j    k

# %%
df1.drop(df1.index[0])
# Out:
#    col1 col2 col3 col4
# d2    c    d    h    i
# d3    e    f    j    k
# d4    0    h    i    k
