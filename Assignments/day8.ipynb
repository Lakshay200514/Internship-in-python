# %%
import pandas as pd
data={1:"a",2:"b",3:"c"}
data1=[1,2,3,4,5,6]
ps=pd.Series(data1,index=["a","b","c","d","e","f"])
df=pd.Series(data) # in the pandas dict we do not give index
print(df)
print(ps)
print(ps[1:6])
print(df[1])
# Out:
# 1    a
# 2    b
# 3    c
# dtype: str
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64
# a

# %%
a=[["a","b"],["c","d"],["e","f"]]
b={
    "emp_name":["A","B","C"],
    "emp_id":[1,2,3]
}
c=[
    ["a","b","c"],
    ["d","e","f"],
    ["g","h","i"]
]
d=[
    ("a","b","c"),
    (1,2,3),
    (45,46,47)
]
e=[
   {
       "name": "A",
        "age": 20,
        "course": "Data Science"
   },
   {
        "brand": "Toyota",
        "model": "Fortuner",
        "year": 2024
   }
]
a=pd.DataFrame(a,columns=["col1","col2"],index=[1,2,3])
b=pd.DataFrame(b,index=[1,2,3])
c=pd.DataFrame(c,columns=["col1","col2","col3"],index=[1,2,3])
d=pd.DataFrame(d,columns=["col1","col2","col3"],index=[1,2,3])
e=pd.DataFrame(e,index=[1,2,3])
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
#   col1 col2
# 1    a    b
# 2    c    d
# 3    e    f
#   emp_name  emp_id
# 1        A       1
# 2        B       2
# 3        C       3
#   col1 col2 col3
# 1    a    b    c
# 2    d    e    f
# 3    g    h    i
#   col1 col2 col3
# 1    a    b    c
# 2    1    2    3
# 3   45   46   47
#   name   age        course   brand     model    year
# 0    A  20.0  Data Science     NaN       NaN     NaN
# 1  NaN   NaN           NaN  Toyota  Fortuner  2024.0

# %%
result=a.loc[1:3,"col1"]
result1=b.loc[1:3,"emp_name"]
result2=b.iloc[1:2,1]
result3=a.drop(1)
result4= a[a["col1"] != "c"]
result5=a.drop([1, 2])
print(c[c["col1"]=="d"])
print(result)
print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
# Out:
#   col1 col2 col3
# 2    d    e    f
# 1    a
# 2    c
# 3    e
# Name: col1, dtype: str
# 1    A
# 2    B
# 3    C
# Name: emp_name, dtype: str
# 2    2
# Name: emp_id, dtype: int64
#   col1 col2
# 2    c    d
# 3    e    f
#   col1 col2
# 1    a    b
# 3    e    f
#   col1 col2
# 3    e    f
